# %%
import pandas as pd
df=pd.read_csv(r"C:\DataScience Assignments\bank-full.csv",delimiter=';')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df=pd.get_dummies(data=df,columns=['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
       'month', 'poutcome'])
df
# Out:
#        age  balance  day  duration  campaign  pdays  previous    y  \
# 0       58     2143    5       261         1     -1         0   no
# 1       44       29    5       151         1     -1         0   no
# 2       33        2    5        76         1     -1         0   no
# 3       47     1506    5        92         1     -1         0   no
# 4       33        1    5       198         1     -1         0   no
# ...    ...      ...  ...       ...       ...    ...       ...  ...
# 45206   51      825   17       977         3     -1         0  yes
# 45207   71     1729   17       456         2     -1         0  yes
# 45208   72     5715   17      1127         5    184         3  yes
# 45209   57      668   17       508         4     -1         0   no
# 45210   37     2971   17       361         2    188        11   no
#
#        job_admin.  job_blue-collar  ...  month_jun  month_mar  month_may  \
# 0           False            False  ...      False      False       True
# ...

# %%
df.head()
# Out:
#    age  balance  day  duration  campaign  pdays  previous   y  job_admin.  \
# 0   58     2143    5       261         1     -1         0  no       False
# 1   44       29    5       151         1     -1         0  no       False
# 2   33        2    5        76         1     -1         0  no       False
# 3   47     1506    5        92         1     -1         0  no       False
# 4   33        1    5       198         1     -1         0  no       False
#
#    job_blue-collar  ...  month_jun  month_mar  month_may  month_nov  \
# 0            False  ...      False      False       True      False
# 1            False  ...      False      False       True      False
# 2            False  ...      False      False       True      False
# 3             True  ...      False      False       True      False
# 4            False  ...      False      False       True      False
#
#    month_oct  month_sep  poutcome_failure  poutcome_other  poutcome_success  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
x=df.drop(columns=['y'])
x.shape
# Out:
# (45211, 51)

# %%
x
# Out:
#        age  balance  day  duration  campaign  pdays  previous  job_admin.  \
# 0       58     2143    5       261         1     -1         0       False
# 1       44       29    5       151         1     -1         0       False
# 2       33        2    5        76         1     -1         0       False
# 3       47     1506    5        92         1     -1         0       False
# 4       33        1    5       198         1     -1         0       False
# ...    ...      ...  ...       ...       ...    ...       ...         ...
# 45206   51      825   17       977         3     -1         0       False
# 45207   71     1729   17       456         2     -1         0       False
# 45208   72     5715   17      1127         5    184         3       False
# 45209   57      668   17       508         4     -1         0       False
# 45210   37     2971   17       361         2    188        11       False
#
#        job_blue-collar  job_entrepreneur  ...  month_jun  month_mar  \
# ...

# %%
y=df['y']
y
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 45206    yes
# 45207    yes
# 45208    yes
# 45209     no
# 45210     no
# Name: y, Length: 45211, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)
y
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
xtrain
# Out:
#        age  balance  day  duration  campaign  pdays  previous  job_admin.  \
# 41626   52      118   25       105         1     -1         0        True
# 31347   28      459   16        83        13     -1         0       False
# 22563   36      156   22       122         1     -1         0       False
# 37243   55      323   13       200         1     -1         0       False
# 32259   38      904   16       361         1    339         1       False
# ...    ...      ...  ...       ...       ...    ...       ...         ...
# 11284   44     1059   18      2093         1     -1         0       False
# 44732   23      508    8       210         1     92         1       False
# 38158   34     1317   15       239         1     -1         0       False
# 860     33      165    7       111         1     -1         0       False
# 15795   38      -41   21        68        10     -1         0       False
#
#        job_blue-collar  job_entrepreneur  ...  month_jun  month_mar  \
# ...

# %%
xtest
# Out:
#        age  balance  day  duration  campaign  pdays  previous  job_admin.  \
# 3776    40      580   16       192         1     -1         0       False
# 9928    47     3644    9        83         2     -1         0       False
# 33409   25      538   20       226         1     -1         0       False
# 31885   42     1773    9       311         1    336         1       False
# 15738   56      217   21       121         2     -1         0       False
# ...    ...      ...  ...       ...       ...    ...       ...         ...
# 13847   55      645   10       123         1     -1         0        True
# 10200   42     2821   11       203         2     -1         0       False
# 32106   43     2557   15       165         2    327         3       False
# 25565   58       60   19       291         2     -1         0       False
# 12758   37     1633    7       629         2     -1         0       False
#
#        job_blue-collar  job_entrepreneur  ...  month_jun  month_mar  \
# ...

# %%
ytrain
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
ytest
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# c:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
ypred=lr.predict(xtest)
ypred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      9950
#            1       0.60      0.20      0.30      1353
#
#     accuracy                           0.89     11303
#    macro avg       0.75      0.59      0.62     11303
# weighted avg       0.86      0.89      0.86     11303

# %%
lr.score(xtrain,ytrain),lr.score(xtest,ytest)
# Out:
# (0.8915300224135897, 0.8882597540475979)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix=confusion_matrix(ytest,ypred)
print(confusion_matrix)
# Out:
# [[9774  176]
#  [1087  266]]

# %%
(9774+266)/(1087+266+9774+176)
# Out:
# 0.8882597540475979

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
fpr,tpr,threshold=roc_curve(ytrain,lr.predict_proba(xtrain)[:,1])
auc=roc_auc_score(ytest,ypred)
plt.plot(fpr,tpr,color='Green')
plt.plot([0,1],[0,1],'k--')
plt.xlabel('FP Rate')
plt.ylabel('TP Rate')
plt.figure(figsize=(10,8))
plt.show()

# %%
auc
# Out:
# 0.5894558528043023

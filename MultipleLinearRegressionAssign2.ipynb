# %% [markdown]
# Q2.Toyoto_Corolla

# %%
import pandas as pd

# %%
data=pd.read_csv("C:\DataScience Assignments\ToyotaCorolla (1).csv",encoding='latin1')

# %%
data.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
data.describe()
# Out:
#                 Id         Price    Age_08_04    Mfg_Month     Mfg_Year  \
# count  1436.000000   1436.000000  1436.000000  1436.000000  1436.000000
# mean    721.555014  10730.824513    55.947075     5.548747  1999.625348
# std     416.476890   3626.964585    18.599988     3.354085     1.540722
# min       1.000000   4350.000000     1.000000     1.000000  1998.000000
# 25%     361.750000   8450.000000    44.000000     3.000000  1998.000000
# 50%     721.500000   9900.000000    61.000000     5.000000  1999.000000
# 75%    1081.250000  11950.000000    70.000000     8.000000  2001.000000
# max    1442.000000  32500.000000    80.000000    12.000000  2004.000000
#
#                   KM           HP    Met_Color    Automatic           cc  ...  \
# count    1436.000000  1436.000000  1436.000000  1436.000000   1436.00000  ...
# mean    68533.259749   101.502089     0.674791     0.055710   1576.85585  ...
# std     37506.448872    14.981080     0.468616     0.229441    424.38677  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
df=data[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]

# %%
df
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
df=df.rename({'Age_08_04':'Age','Quarterly_Tax':'QT'})

# %%
df
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1431   7500   69  20544   86  1300      3      5   69    1025
# 1432  10845   72  19000   86  1300      3      5   69    1015
# 1433   8500   71  17016   86  1300      3      5   69    1015
# 1434   7250   70  16916   86  1300      3      5   69    1015
# 1435   6950   76      1  110  1600      5      5   19    1114
#
# [1436 rows x 9 columns]

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df=df.drop_duplicates().reset_index(drop=True)

# %%
df
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Price, Age, KM, HP, cc, Doors, Gears, QT, Weight]
# Index: []

# %%
import seaborn as sns
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %%
ndata=df.iloc[:,1:]

# %%
ndata
# Out:
#       Age     KM   HP    cc  Doors  Gears   QT  Weight
# 0      23  46986   90  2000      3      5  210    1165
# 1      23  72937   90  2000      3      5  210    1165
# 2      24  41711   90  2000      3      5  210    1165
# 3      26  48000   90  2000      3      5  210    1165
# 4      30  38500   90  2000      3      5  210    1170
# ...   ...    ...  ...   ...    ...    ...  ...     ...
# 1430   69  20544   86  1300      3      5   69    1025
# 1431   72  19000   86  1300      3      5   69    1015
# 1432   71  17016   86  1300      3      5   69    1015
# 1433   70  16916   86  1300      3      5   69    1015
# 1434   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 8 columns]

# %%
ndata.values
# Out:
# array([[   23, 46986,    90, ...,     5,   210,  1165],
#        [   23, 72937,    90, ...,     5,   210,  1165],
#        [   24, 41711,    90, ...,     5,   210,  1165],
#        ...,
#        [   71, 17016,    86, ...,     5,    69,  1015],
#        [   70, 16916,    86, ...,     5,    69,  1015],
#        [   76,     1,   110, ...,     5,    19,  1114]], dtype=int64)

# %%
vif=pd.DataFrame()
vif
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
vif['features']=ndata.columns
vif
# Out:
#   features
# 0      Age
# 1       KM
# 2       HP
# 3       cc
# 4    Doors
# 5    Gears
# 6       QT
# 7   Weight

# %%
vif['vif']=[variance_inflation_factor(ndata.values,i) for i in range(len(ndata.columns))]
vif
# Out:
#   features         vif
# 0      Age   16.392665
# 1       KM    7.601207
# 2       HP   64.894446
# 3       cc   17.186097
# 4    Doors   21.856114
# 5    Gears  439.672599
# 6       QT   11.021647
# 7   Weight  543.522036

# %%
df.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
x
# Out:
#       Age     KM   HP    cc  Doors  Gears   QT  Weight
# 0      23  46986   90  2000      3      5  210    1165
# 1      23  72937   90  2000      3      5  210    1165
# 2      24  41711   90  2000      3      5  210    1165
# 3      26  48000   90  2000      3      5  210    1165
# 4      30  38500   90  2000      3      5  210    1170
# ...   ...    ...  ...   ...    ...    ...  ...     ...
# 1430   69  20544   86  1300      3      5   69    1025
# 1431   72  19000   86  1300      3      5   69    1015
# 1432   71  17016   86  1300      3      5   69    1015
# 1433   70  16916   86  1300      3      5   69    1015
# 1434   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 8 columns]

# %%
y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1430     7500
# 1431    10845
# 1432     8500
# 1433     7250
# 1434     6950
# Name: Price, Length: 1435, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_scaled=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x_scaled,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(xtest)
y_pred
# Out:
# array([10644.75880869, 10397.49164331,  9492.50540724,  9497.64769846,
#         8523.649602  ,  8357.39091753,  8233.07813878,  8351.5532451 ,
#        11882.59412718, 12539.95956847,  9354.31158623,  9428.7496349 ,
#        13310.90026615, 12443.68526177,  8882.51515866, 11664.96967886,
#        12432.06412195, 17460.75741832, 11219.00687622, 11667.20288104,
#        11748.31623269, 18013.79691335,  9948.08737199, 10555.18016684,
#         7333.88962611, 15981.85556939,  7130.04871483,  8539.64344908,
#        15474.70181267, 13955.82393884,  8152.08728372, 10954.42167286,
#        10183.66360112, 10162.15247847, 10183.62456396,  8606.29271892,
#         8967.98453732, 10025.33697999, 16182.08978172, 10763.51152238,
#         8630.49398217,  9592.32612142, 10122.00878104,  8536.35026986,
#        10696.87378374, 17438.05646525, 10037.80828722,  8815.99247301,
#        10920.24444904, 12933.00735704, 13009.47023237,  6307.24961199,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(ytrain,reg.predict(xtrain))
# Out:
# 0.8656289195324184

# %%
r2_score(ytest,y_pred)
# Out:
# 0.8520479511940463

# %%
df.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %%
import statsmodels.formula.api as smf
model=smf.ols('Price~Age+KM+HP+cc+Doors+Gears+QT+Weight',data=df).fit()

# %%
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# cc             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QT              3.858805
# Weight         16.855470
# dtype: float64

# %%
model.pvalues
# Out:
# Intercept     1.113392e-04
# Age          1.879217e-288
# KM            1.994713e-56
# HP            5.211155e-28
# cc            1.882393e-01
# Doors         9.816443e-01
# Gears         2.452430e-03
# QT            3.290363e-03
# Weight        1.031118e-51
# dtype: float64

# %%
model.rsquared,model.aic
# Out:
# (0.8625200256947, 24750.407207346932)

# %%
df
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
model.fittedvalues
# Out:
# 0       16791.958871
# 1       16253.800414
# 2       16779.635210
# 3       16405.789389
# 4       16200.217277
#             ...
# 1430     8794.255037
# 1431     8292.577342
# 1432     8455.434402
# 1433     8579.222041
# 1434    10396.087526
# Length: 1435, dtype: float64

# %%
model.resid
# Out:
# 0      -3291.958871
# 1      -2503.800414
# 2      -2829.635210
# 3      -1455.789389
# 4      -2450.217277
#            ...
# 1430   -1294.255037
# 1431    2552.422658
# 1432      44.565598
# 1433   -1329.222041
# 1434   -3446.087526
# Length: 1435, dtype: float64

# %%
import statsmodels.api as sm
sm.qqplot(model.resid,line='q')

# %%
import numpy as np
np.argmax(model.resid),np.max(model.resid)
# Out:
# (522, 6445.391160058924)

# %%
import matplotlib.pyplot as plt
plt.scatter(model.fittedvalues,model.resid)
plt.xlabel('Fitted Values')
plt.ylabel('Errors')
# Out:
# Text(0, 0.5, 'Errors')

# %%
plt.rcParams['figure.figsize']=(15,7)
sm.graphics.plot_regress_exog(model,'Age')

# %%
sm.graphics.plot_fit(model,'Age')

# %%
sm.graphics.plot_fit(model,'KM')

# %%
sm.graphics.plot_fit(model,'Doors')

# %%
inf=model.get_influence()
c,p=inf.cooks_distance

# %%
c
# Out:
# array([7.22221054e-03, 3.94547973e-03, 5.44224039e-03, ...,
#        8.04110551e-07, 6.99854767e-04, 1.08408002e-02])

# %%
plt.stem(c)
plt.xlabel('index')
plt.ylabel('cooks distance')
# Out:
# Text(0, 0.5, 'cooks distance')

# %%
np.argmax(c),np.max(c)
# Out:
# (80, 78.7295058225869)

# %%
data.iloc[[80]]
# Out:
#     Id                                Model  Price  Age_08_04  Mfg_Month  \
# 80  81  TOYOTA Corolla 1.6 5drs 1 4/5-Doors  18950         25          8
#
#     Mfg_Year     KM Fuel_Type   HP  Met_Color  ... Central_Lock  \
# 80      2002  20019    Petrol  110          1  ...            1
#
#     Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# 80                1               1      0          0            0
#
#     Backseat_Divider  Metallic_Rim  Radio_cassette  Tow_Bar
# 80                 0             0               0        0
#
# [1 rows x 38 columns]

# %%
df.drop(index=[80],inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'],inplace=True)

# %%
df.head()
# Out:
#    Price  Age     KM  HP    cc  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %%
import statsmodels.formula.api as smf
finalmodel=smf.ols('Price~Age+KM+HP+cc+Doors+Gears+QT+Weight',data=df).fit()

# %%
finalmodel.params
# Out:
# Intercept   -6197.933399
# Age          -120.507430
# KM             -0.017799
# HP             39.224550
# cc             -2.508791
# Doors         -26.512930
# Gears         527.129216
# QT              8.941399
# Weight         20.062713
# dtype: float64

# %%
finalmodel.pvalues
# Out:
# Intercept     8.123945e-06
# Age          2.336818e-292
# KM            1.868674e-41
# HP            5.123463e-39
# cc            7.178158e-16
# Doors         4.993149e-01
# Gears         6.341805e-03
# QT            4.846286e-10
# Weight        4.509449e-65
# dtype: float64

# %%
finalmodel.rsquared,finalmodel.aic
# Out:
# (0.8681163912634053, 24669.363894157)

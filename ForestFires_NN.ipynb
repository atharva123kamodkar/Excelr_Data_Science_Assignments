# %%
import pandas as pd
df=pd.read_csv(r'C:\DataScience Assignments\Neural Networks\forestfires.csv')
df
# Out:
#     month  day  FFMC    DMC  ...  monthnov  monthoct  monthsep  size_category
# 0     mar  fri  86.2   26.2  ...         0         0         0          small
# 1     oct  tue  90.6   35.4  ...         0         1         0          small
# 2     oct  sat  90.6   43.7  ...         0         1         0          small
# 3     mar  fri  91.7   33.3  ...         0         0         0          small
# 4     mar  sun  89.3   51.3  ...         0         0         0          small
# ..    ...  ...   ...    ...  ...       ...       ...       ...            ...
# 512   aug  sun  81.6   56.7  ...         0         0         0          large
# 513   aug  sun  81.6   56.7  ...         0         0         0          large
# 514   aug  sun  81.6   56.7  ...         0         0         0          large
# 515   aug  sat  94.4  146.0  ...         0         0         0          small
# 516   nov  tue  79.5    3.0  ...         1         0         0          small
#
# [517 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   month          517 non-null    object
#  1   day            517 non-null    object
#  2   FFMC           517 non-null    float64
#  3   DMC            517 non-null    float64
#  4   DC             517 non-null    float64
#  5   ISI            517 non-null    float64
#  6   temp           517 non-null    float64
#  7   RH             517 non-null    int64
#  8   wind           517 non-null    float64
#  9   rain           517 non-null    float64
#  10  area           517 non-null    float64
#  11  dayfri         517 non-null    int64
#  12  daymon         517 non-null    int64
#  13  daysat         517 non-null    int64
#  14  daysun         517 non-null    int64
#  15  daythu         517 non-null    int64
#  16  daytue         517 non-null    int64
# ...

# %%
data=df.iloc[:,2:]
data
# Out:
#      FFMC    DMC     DC   ISI  ...  monthnov  monthoct  monthsep  size_category
# 0    86.2   26.2   94.3   5.1  ...         0         0         0          small
# 1    90.6   35.4  669.1   6.7  ...         0         1         0          small
# 2    90.6   43.7  686.9   6.7  ...         0         1         0          small
# 3    91.7   33.3   77.5   9.0  ...         0         0         0          small
# 4    89.3   51.3  102.2   9.6  ...         0         0         0          small
# ..    ...    ...    ...   ...  ...       ...       ...       ...            ...
# 512  81.6   56.7  665.6   1.9  ...         0         0         0          large
# 513  81.6   56.7  665.6   1.9  ...         0         0         0          large
# 514  81.6   56.7  665.6   1.9  ...         0         0         0          large
# 515  94.4  146.0  614.7  11.3  ...         0         0         0          small
# 516  79.5    3.0  106.7   1.1  ...         1         0         0          small
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 29 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FFMC           517 non-null    float64
#  1   DMC            517 non-null    float64
#  2   DC             517 non-null    float64
#  3   ISI            517 non-null    float64
#  4   temp           517 non-null    float64
#  5   RH             517 non-null    int64
#  6   wind           517 non-null    float64
#  7   rain           517 non-null    float64
#  8   area           517 non-null    float64
#  9   dayfri         517 non-null    int64
#  10  daymon         517 non-null    int64
#  11  daysat         517 non-null    int64
#  12  daysun         517 non-null    int64
#  13  daythu         517 non-null    int64
#  14  daytue         517 non-null    int64
#  15  daywed         517 non-null    int64
#  16  monthapr       517 non-null    int64
# ...

# %%
data.describe()
# Out:
#              FFMC         DMC          DC  ...    monthnov    monthoct    monthsep
# count  517.000000  517.000000  517.000000  ...  517.000000  517.000000  517.000000
# mean    90.644681  110.872340  547.940039  ...    0.001934    0.029014    0.332689
# std      5.520111   64.046482  248.066192  ...    0.043980    0.168007    0.471632
# min     18.700000    1.100000    7.900000  ...    0.000000    0.000000    0.000000
# 25%     90.200000   68.600000  437.700000  ...    0.000000    0.000000    0.000000
# 50%     91.600000  108.300000  664.200000  ...    0.000000    0.000000    0.000000
# 75%     92.900000  142.400000  713.900000  ...    0.000000    0.000000    1.000000
# max     96.200000  291.300000  860.600000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 28 columns]

# %%
data.isna().sum()
# Out:
# FFMC             0
# DMC              0
# DC               0
# ISI              0
# temp             0
# RH               0
# wind             0
# rain             0
# area             0
# dayfri           0
# daymon           0
# daysat           0
# daysun           0
# daythu           0
# daytue           0
# daywed           0
# monthapr         0
# monthaug         0
# monthdec         0
# monthfeb         0
# monthjan         0
# monthjul         0
# monthjun         0
# monthmar         0
# monthmay         0
# monthnov         0
# monthoct         0
# monthsep         0
# size_category    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 8

# %%
data[data.duplicated()]
# Out:
#      FFMC    DMC     DC   ISI  ...  monthnov  monthoct  monthsep  size_category
# 53   92.1  111.2  654.1   9.6  ...         0         0         0          small
# 100  91.4  142.4  601.4  10.6  ...         0         0         0          small
# 215  91.7   35.8   80.8   7.8  ...         0         0         0          large
# 303  91.1   94.1  232.1   7.1  ...         0         0         0          small
# 426  91.6  248.4  753.8   6.3  ...         0         0         0          small
# 461  93.7  231.1  715.1   8.4  ...         0         0         0          small
# 501  96.1  181.1  671.2  14.3  ...         0         0         0          small
# 508  91.0  166.9  752.6   7.1  ...         0         0         0          small
#
# [8 rows x 29 columns]

# %%
data.shape
# Out:
# (517, 29)

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#      FFMC    DMC     DC   ISI  ...  monthnov  monthoct  monthsep  size_category
# 0    86.2   26.2   94.3   5.1  ...         0         0         0          small
# 1    90.6   35.4  669.1   6.7  ...         0         1         0          small
# 2    90.6   43.7  686.9   6.7  ...         0         1         0          small
# 3    91.7   33.3   77.5   9.0  ...         0         0         0          small
# 4    89.3   51.3  102.2   9.6  ...         0         0         0          small
# ..    ...    ...    ...   ...  ...       ...       ...       ...            ...
# 512  81.6   56.7  665.6   1.9  ...         0         0         0          large
# 513  81.6   56.7  665.6   1.9  ...         0         0         0          large
# 514  81.6   56.7  665.6   1.9  ...         0         0         0          large
# 515  94.4  146.0  614.7  11.3  ...         0         0         0          small
# 516  79.5    3.0  106.7   1.1  ...         1         0         0          small
#
# ...

# %%
data.shape
# Out:
# (509, 29)

# %%
data.reset_index(drop=True)
data
# Out:
#      FFMC    DMC     DC   ISI  ...  monthnov  monthoct  monthsep  size_category
# 0    86.2   26.2   94.3   5.1  ...         0         0         0          small
# 1    90.6   35.4  669.1   6.7  ...         0         1         0          small
# 2    90.6   43.7  686.9   6.7  ...         0         1         0          small
# 3    91.7   33.3   77.5   9.0  ...         0         0         0          small
# 4    89.3   51.3  102.2   9.6  ...         0         0         0          small
# ..    ...    ...    ...   ...  ...       ...       ...       ...            ...
# 512  81.6   56.7  665.6   1.9  ...         0         0         0          large
# 513  81.6   56.7  665.6   1.9  ...         0         0         0          large
# 514  81.6   56.7  665.6   1.9  ...         0         0         0          large
# 515  94.4  146.0  614.7  11.3  ...         0         0         0          small
# 516  79.5    3.0  106.7   1.1  ...         1         0         0          small
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['size_category']=le.fit_transform(data['size_category'])
data
# Out:
#      FFMC    DMC     DC   ISI  ...  monthnov  monthoct  monthsep  size_category
# 0    86.2   26.2   94.3   5.1  ...         0         0         0              1
# 1    90.6   35.4  669.1   6.7  ...         0         1         0              1
# 2    90.6   43.7  686.9   6.7  ...         0         1         0              1
# 3    91.7   33.3   77.5   9.0  ...         0         0         0              1
# 4    89.3   51.3  102.2   9.6  ...         0         0         0              1
# ..    ...    ...    ...   ...  ...       ...       ...       ...            ...
# 512  81.6   56.7  665.6   1.9  ...         0         0         0              0
# 513  81.6   56.7  665.6   1.9  ...         0         0         0              0
# 514  81.6   56.7  665.6   1.9  ...         0         0         0              0
# 515  94.4  146.0  614.7  11.3  ...         0         0         0              1
# 516  79.5    3.0  106.7   1.1  ...         1         0         0              1
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def plot_distplots(df):
    for column in df.columns:
        plt.figure(figsize=(8,6))
        sns.distplot(df[column],kde=False,bins=30,color='blue')
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()

# %%
plot_distplots(data)
# Out:
# C:\Users\Shree\AppData\Local\Temp\ipykernel_13700\38252377.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column],kde=False,bins=30,color='blue')

# %%
data.corr()
# Out:
#                    FFMC       DMC        DC  ...  monthoct  monthsep  size_category
# FFMC           1.000000  0.382925  0.331956  ... -0.005172  0.080444      -0.024292
# DMC            0.382925  1.000000  0.681446  ... -0.188126  0.119779      -0.046598
# DC             0.331956  0.681446  1.000000  ...  0.094091  0.538299      -0.028372
# ISI            0.531926  0.309459  0.229757  ... -0.071401 -0.069600       0.007867
# temp           0.431744  0.470875  0.496608  ... -0.052918  0.091428      -0.009976
# RH            -0.306262  0.062772 -0.047971  ... -0.072335 -0.061631       0.039730
# wind          -0.030409 -0.104563 -0.202856  ... -0.053404 -0.180211      -0.059513
# rain           0.052280  0.071017  0.033772  ... -0.012030 -0.049319      -0.053463
# area           0.040998  0.076932  0.051542  ... -0.017284  0.055191      -0.310561
# dayfri         0.020889 -0.011152 -0.001642  ... -0.045470  0.111903       0.017980
# ...

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
x=data.drop('size_category',axis=1)
x
# Out:
#      FFMC    DMC     DC   ISI  ...  monthmay  monthnov  monthoct  monthsep
# 0    86.2   26.2   94.3   5.1  ...         0         0         0         0
# 1    90.6   35.4  669.1   6.7  ...         0         0         1         0
# 2    90.6   43.7  686.9   6.7  ...         0         0         1         0
# 3    91.7   33.3   77.5   9.0  ...         0         0         0         0
# 4    89.3   51.3  102.2   9.6  ...         0         0         0         0
# ..    ...    ...    ...   ...  ...       ...       ...       ...       ...
# 512  81.6   56.7  665.6   1.9  ...         0         0         0         0
# 513  81.6   56.7  665.6   1.9  ...         0         0         0         0
# 514  81.6   56.7  665.6   1.9  ...         0         0         0         0
# 515  94.4  146.0  614.7  11.3  ...         0         0         0         0
# 516  79.5    3.0  106.7   1.1  ...         0         1         0         0
#
# [509 rows x 28 columns]

# %%
y=data['size_category']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 512    0
# 513    0
# 514    0
# 515    1
# 516    1
# Name: size_category, Length: 509, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-7.96039810e-01, -1.31838569e+00, -1.82893094e+00, ...,
#         -4.43678255e-02, -1.74253759e-01, -7.14412875e-01],
#        [-3.25665522e-03, -1.17405250e+00,  4.89256926e-01, ...,
#         -4.43678255e-02,  5.73875712e+00, -7.14412875e-01],
#        [-3.25665522e-03, -1.04383887e+00,  5.61044929e-01, ...,
#         -4.43678255e-02,  5.73875712e+00, -7.14412875e-01],
#        ...,
#        [-1.62485856e+00, -8.39889805e-01,  4.75141308e-01, ...,
#         -4.43678255e-02, -1.74253759e-01, -7.14412875e-01],
#        [ 6.81419706e-01,  5.61083388e-01,  2.69859884e-01, ...,
#         -4.43678255e-02, -1.74253759e-01, -7.14412875e-01],
#        [-2.00323234e+00, -1.68235633e+00, -1.77892132e+00, ...,
#          2.25388553e+01, -1.74253759e-01, -7.14412875e-01]])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from kerastuner.tuners import RandomSearch

# %%
def build_model(hp):
    model=Sequential()
    model.add(Dense(units=hp.Int('units',min_value=8,max_value=128,step=8),
                   activation=hp.Choice('actication',values=['relu','tanh','sigmoid'])))
    model.add(Dense(units=1,activation='sigmoid'))
    model.compile(optimizer=hp.Choice('optimizer',values=['adam','rmsprop','adadelta']),
                 loss='binary_crossentropy',
                 metrics=['accuracy'])
    return model

# %%
tuner=RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5
)

# %%
tuner.search(xtrain,ytrain,epochs=50,validation_data=(xtest,ytest))
# Out:
# Trial 5 Complete [00h 00m 07s]
# val_accuracy: 0.8203125
#
# Best val_accuracy So Far: 0.8203125
# Total elapsed time: 00h 00m 50s

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(best_hps)

# %%
model=tuner.hypermodel.build(best_hps)
history=model.fit(xtrain,ytrain,validation_data=(xtest,ytest),epochs=50)
history
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5485 - loss: 0.6792 - val_accuracy: 0.6953 - val_loss: 0.6310
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7287 - loss: 0.5899 - val_accuracy: 0.7109 - val_loss: 0.6029
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7454 - loss: 0.5543 - val_accuracy: 0.7188 - val_loss: 0.5888
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7697 - loss: 0.5354 - val_accuracy: 0.7344 - val_loss: 0.5779
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7487 - loss: 0.5243 - val_accuracy: 0.7500 - val_loss: 0.5678
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7898 - loss: 0.4786 - val_accuracy: 0.7578 - val_loss: 0.5616
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7463 - loss: 0.5104 - val_accuracy: 0.7578 - val_loss: 0.5557
# Epoch 8/50
# ...

# %%
model.evaluate(xtest,ytest)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8417 - loss: 0.4176
# [0.46533554792404175, 0.8046875]

# %%
y_pred=model.predict(xtest)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred
# Out:
# array([[9.5763576e-01],
#        [8.1745386e-01],
#        [6.3422430e-01],
#        [8.8190794e-01],
#        [8.2458031e-01],
#        [8.9226389e-01],
#        [9.6065873e-01],
#        [9.0373117e-01],
#        [7.4290562e-01],
#        [9.1051811e-01],
#        [7.5244099e-01],
#        [9.0522254e-01],
#        [8.8647681e-01],
#        [8.4519720e-01],
#        [7.9389596e-01],
#        [3.7556611e-09],
#        [9.3661904e-01],
#        [7.7093387e-01],
#        [7.9647064e-01],
#        [8.9607847e-01],
#        [7.3952651e-01],
#        [7.4737769e-01],
#        [8.5977113e-01],
#        [6.4216989e-01],
#        [8.6214828e-01],
#        [7.2546142e-01],
#        [9.1291320e-01],
#        [8.8688189e-01],
#        [8.9009756e-01],
#        [1.8402271e-04],
#        [9.7074431e-01],
#        [2.7907974e-01],
#        [9.8079425e-01],
#        [6.6095602e-04],
#        [8.1902899e-06],
#        [6.8519187e-01],
#        [7.3968470e-01],
#        [9.5174760e-01],
# ...
